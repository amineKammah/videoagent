# %% [markdown]
# # Story Generator Playground
#
# Use this notebook to step through `PersonalizedStoryGenerator` and inspect inputs/outputs.
#
# Notes:
# - The LLM calls require `GEMINI_API_KEY` (or ADC).
# - Update `library_path` to point at your video library.
# - Output is a list of 4 segments: intro, pain scene, solution clip, testimonial clip.

# %%
import os

# Ensure /opt/homebrew/bin is on PATH for ffprobe.
if '/opt/homebrew/bin' not in os.environ.get('PATH', ''):
    os.environ['PATH'] = '/opt/homebrew/bin:' + os.environ.get('PATH', '')

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
SRC = ROOT / 'backend' / 'src'
if SRC.exists() and str(SRC) not in sys.path:
    sys.path.append(str(SRC))

try:
    from dotenv import load_dotenv
    load_dotenv(ROOT / '.env')
except ImportError:
    pass

from videoagent.config import Config
from videoagent.story import PersonalizedStoryGenerator

# %%
# Point this at your video library (default in Config is ./videos).
library_path = Path('/Users/amineka/Downloads/Navan_Content/normalized_videos')
transcript_path = Path('/Users/amineka/Downloads/Navan_Content/normalized_transcripts')
output_dir = ROOT / 'output'

config = Config(
    video_library_path=library_path,
    transcript_library_path=transcript_path,
    output_dir=output_dir,
)
generator = PersonalizedStoryGenerator(config)

# %%
# Scan and list available videos.
generator.library.scan_library()
videos = generator.library.list_videos()

# %%
videos[2].get_full_transcript()
# Out:
# "[0.00-5.10] Fever-Tree's headquarters are in London [5.10-10.90] and we also have offices in Munich, New York and Sydney. [10.90-13.50] Fever-Tree sell premium mixers. [13.50-17.50] We're currently in the Fever-Tree Bar and this is what we call our brand home. [17.50-22.10] It's really important for the Fever-Tree sales team to meet with our customers [22.10-26.00] in a space such as this so that we can demonstrate our products in this premium environment. [26.00-30.20] Fever-Tree had a travel and expense policy in place. [30.20-34.60] It was a document that was circulated amongst staff and it was up to the individuals [34.60-37.80] to make sure that they complied with that policy. [37.80-42.00] People tended to book their own travel and claim that back through expenses. [42.00-46.80] So we wanted to create a single process for people to book through the platform. [46.80-51.50] And we wanted to be able to embed the travel within that expense process as well. [51.50-56.40] I think some of the pain points that we experienced managing travel was just the unknown. [56.40-61.20] We didn't necessarily know who was traveling when until we received an expense coming in. [61.20-66.50] So it was always a case that we were quite reactive to the process rather than being proactive, [66.50-71.10] knowing when people are, signing off travel ahead of time [71.10-73.80] and understanding why that travel is taking place. [73.80-76.50] That process now has largely gone away. [76.50-81.30] People are reimbursed as the expense happens and the travel is booked and paid for through [81.30-84.70] a virtual card rather than on individual's expenses. [84.70-87.80] We've saved 2 days from the finance team on a monthly basis [87.80-93.40] in terms of administering expenses and reimbursing people because those monthly processes [93.40-95.80] were quite manual before. [95.80-99.80] On the traveler's side, there's also been savings in terms of booking those flights [99.80-105.00] through the platform or hotels, but also less time in then having to upload receipts [105.00-110.00] for their flights, for the hotels, and for other expenses that they might be incurring. [110.00-115.30] My favorite travel feature is that we can know where all our travelers are at any given time. [115.30-118.80] That really helps with any kind of duty of care. [118.80-122.10] Navan enables us to do carbon reporting on our travel, [122.10-126.50] giving us those insights on our carbon emissions that will be really useful [126.50-132.00] in terms of understanding our carbon footprint as a business and understanding how we can [132.00-135.20] manage that through our sustainability team. [135.20-139.50] With Navan we are able to manage our cost much more effectively [139.50-143.50] because we have much better visibility over what we're spending on a real time basis. [143.50-148.80] We've made 14% savings on flights and 22% savings on hotels. [148.80-153.10] Most employees have access to a Navan card at Fever-Tree [153.10-157.00] and that is based on whether they are spending a significant amount of time on travel. [157.00-161.40] My favorite expense feature in Navan is the fact that I can do pretty much everything on my phone. [161.40-166.30] I can record all of my expenses as I use my Navan card. [166.30-170.80] The expense immediately pops up and I can add the receipt in real time. [170.80-173.80] So it's super convenient. [173.80-179.30] Realtime visibility and reporting has been one of the key selling points for us with Navan. [179.30-184.80] It's enabled us to understand trips as they are happening [184.80-189.60] and then the cost is immediately updated in any kind of dashboard or report. [189.60-194.20] So we can immediately see how we're tracking against budget. [194.20-197.80] Our employees are enjoying using Navan. [197.80-202.80] We have a customer satisfaction rate of 4.9 out of 5, which is really positive. [202.80-209.10] If I had to describe Navan, it would be that it' ...

# %%
customer_situation = (
    'Our finance team is spending hours each week reconciling travel expenses. '
    'We need a faster way to capture receipts and sync them into accounting.'
)

# %%
# Generate the 4 story segments.
segments = await generator.generate_segments(customer_situation)
segments
# Out:
# Story: scanning video library...
# Story: scan completed in 0.02s
# Story: collecting transcripts...
# Story: transcripts collected in 0.00s
# Story: planning storyboard + voice overs...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Generate the 4 story segments.
# ----> 2 segments = await generator.generate_segments(customer_situation)
#       3 segments
#
# File ~/videoagent/backend/src/videoagent/story.py:309, in PersonalizedStoryGenerator.generate_segments(self, customer_situation)
#     307 step_start = time.perf_counter()
#     308 print("Story: planning storyboard + voice overs...")
# --> 309 storyboard = self._plan_storyboard(customer_situation, videos_summary)
#     310 print(f"Story: storyboard planned in {time.perf_counter() - step_start:.2f}s")
#     312 selected_video_ids = self._normalize_top_video_ids(storyboard.top_video_ids)
#
# File ~/videoagent/backend/src/videoagent/story.py:200, in PersonalizedStoryGenerator._plan_storyboard(self, customer_situation, videos_transcripts)
#     182         """Ask the LLM for a storyboard plan in structured output."""
#     183         prompt = f"""You are a senior video editor creating a short, personalized sales video.
#     184 Take a deep breath and think for a long time before answering.
#     185
#    (...)    197 Return a JSON object that matches the provided schema.
#     198 """
# --> 200         response = self.client.generate_content(
#     201             model=self.config.gemini_model,
#     202             contents=prompt,
#     203             config={
#     204                 "response_mime_type": "application/json",
#     205                 "response_json_schema": _StoryboardPlan.model_json_schema(),
#     206             },
#     207         )
#     209         return _StoryboardPlan.model_validate_json(response.text)
#
# File ~/videoagent/backend/src/videoagent/gemini.py:104, in GeminiClient.generate_content(self, model, contents, config)
#      87 def generate_content(
#      88     self,
#      89     model: str,
#      90     contents: list,
#      91     config: Optional[dict] = None,
#      92 ):
#      93     """
#      94     Generate content using Gemini.
#      95
#    (...)    102         Response object
#     103     """
# --> 104     return self._get_content_client().models.generate_content(
#     105         model=model,
#     106         contents=contents,
#     107         config=config,
#     108     )
#
# File ~/videoagent/backend/src/videoagent/gemini.py:66, in GeminiClient._get_content_client(self)
#      64 def _get_content_client(self):
#      65     if self._content_client is None:
# ---> 66         self._content_client = self._create_client()
#      67     return self._content_client
#
# File ~/videoagent/backend/src/videoagent/gemini.py:53, in GeminiClient._create_client(self)
#      49     # credentials_path = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
#      50     # credentials = service_account.Credentials.from_service_account_file(credentials_path)
#      51     api_key = os.getenv("GEMINI_API_KEY")
# ---> 53     return genai.Client(
#      54         vertexai=False,
#      55         api_key=api_key,
#      56     )
#      58 except ImportError:
#      59     raise RuntimeError(
#      60         "google-genai not installed. "
#      61         "Install with: pip install google-genai"
#      62     )
#
# File ~/videoagent/.venv/lib/python3.13/site-packages/google/genai/client.py:396, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     393   else:
#     394     http_options = HttpOptions(base_url=base_url)
# --> 396 self._api_client = self._get_api_client(
#     397     vertexai=vertexai,
#     398     api_key=api_key,
#     399     credentials=credentials,
#     400     project=project,
#     401     location=location,
#     402     debug_config=self._debug_config,
#     403     http_options=http_options,
#     404 )
#     406 self._aio = AsyncClient(self._api_client)
#     407 self._models = Models(self._api_client)
#
# File ~/videoagent/.venv/lib/python3.13/site-packages/google/genai/client.py:444, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     427 if debug_config and debug_config.client_mode in [
#     428     'record',
#     429     'replay',
#     430     'auto',
#     431 ]:
#     432   return ReplayApiClient(
#     433       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     434       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    441       http_options=http_options,
#     442   )
# --> 444 return BaseApiClient(
#     445     vertexai=vertexai,
#     446     api_key=api_key,
#     447     credentials=credentials,
#     448     project=project,
#     449     location=location,
#     450     http_options=http_options,
#     451 )
#
# File ~/videoagent/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:683, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     681 else:  # Implicit initialization or missing arguments.
#     682   if not self.api_key:
# --> 683     raise ValueError(
#     684         'Missing key inputs argument! To use the Google AI API,'
#     685         ' provide (`api_key`) arguments. To use the Google Cloud API,'
#     686         ' provide (`vertexai`, `project` & `location`) arguments.'
#     687     )
#     688   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     689   self._http_options.api_version = 'v1beta'
#
# ValueError: Missing key inputs argument! To use the Google AI API, provide (`api_key`) arguments. To use the Google Cloud API, provide (`vertexai`, `project` & `location`) arguments.

# %%
# Quick summary of the segments.
[(seg.segment_type.value, type(seg.content).__name__, round(seg.duration, 2)) for seg in segments]
# Out:
# [('video_clip', 'VideoSegment', 15.0),
#  ('video_clip', 'VideoSegment', 13.53),
#  ('video_clip', 'VideoSegment', 20.45),
#  ('video_clip', 'VideoSegment', 9.36),
#  ('video_clip', 'VideoSegment', 19.17)]

# %%
# Intro segment
intro_segment = segments[0]
intro_segment
# Out:
# StorySegment(segment_type=<SegmentType.VIDEO_CLIP: 'video_clip'>, content=VideoSegment(source_video_id='375bda519fb0', source_path=PosixPath('/Users/amineka/Downloads/Navan_Content/normalized_videos/SumUp_switches_to_Navan_and_sees_big_savings_and_a_23_increase_in_platform_adoption_61.mp4'), start_time=29.0, end_time=44.0, description='A SumUp representative describes their previous travel and expense handling as a "nightmare" involving manual out-of-pocket expenses, struggling with receipts and reimbursements.', keep_original_audio=False, audio_volume=1.0), voice_over=VoiceOver(script='Is your finance team drowning in manual expense reconciliation, spending countless hours each week just trying to keep up with receipts and reimbursements? You need a faster, more efficient way to manage expenses and get that data into accounting.', audio_path=PosixPath('/var/folders/3v/hwmhcj3912587f0tqnv0wg3w0000gn/T/voice_over_oekw0bd0/vo_298eb858.wav'), duration=17.010958, voice='Kore', speed=1.0, volume=1.0, id='017bfff2'), vo_timing_strategy=None, order=0, id='04cbd805')

# %%
# Pain segment
pain_segment = segments[1]
pain_segment
# Out:
# StorySegment(segment_type=<SegmentType.VIDEO_CLIP: 'video_clip'>, content=VideoSegment(source_video_id='73632ffece2d', source_path=PosixPath('/Users/amineka/Downloads/Navan_Content/normalized_videos/How_to_submit_a_manual_expense_40_2.mp4'), start_time=28.0, end_time=39.970957999999996, description='A user demonstrates the Navan app, scanning a receipt with their phone, capturing the details, and instantly matching them to a transaction.', keep_original_audio=False, audio_volume=1.0), voice_over=VoiceOver(script='Imagine a world where capturing receipts is effortless. With Navan, employees simply use their phone to snap a photo of a receipt, and the details are instantly captured and matched to the transaction.', audio_path=PosixPath('/var/folders/3v/hwmhcj3912587f0tqnv0wg3w0000gn/T/voice_over_oekw0bd0/vo_bf295adf.wav'), duration=11.970958, voice='Kore', speed=1.0, volume=1.0, id='433a4b20'), vo_timing_strategy=None, order=1, id='038f84e1')

# %%
# Solution segment
solution_segment = segments[2]
solution_segment
# Out:
# StorySegment(segment_type=<SegmentType.VIDEO_CLIP: 'video_clip'>, content=VideoSegment(source_video_id='1f40b39c9304', source_path=PosixPath('/Users/amineka/Downloads/Navan_Content/normalized_videos/Meet_Navan_the_Industrys_Best_Travel_and_Expense_Solution_68.mp4'), start_time=78.0, end_time=92.0, description='The video explains how Navan allows travelers to track spend against company policies in real-time, automatically capturing and categorizing transactions to eliminate time-consuming expense reports.', keep_original_audio=False, audio_volume=1.0), voice_over=VoiceOver(script='From swipe to reconciliation, Navan automates expenses. With corporate cards linked, transactions are automatically categorized, policies are applied, and expenses are approved in real-time, removing the need for manual reports.', audio_path=PosixPath('/var/folders/3v/hwmhcj3912587f0tqnv0wg3w0000gn/T/voice_over_oekw0bd0/vo_d7b05d0b.wav'), duration=15.730958, voice='Kore', speed=1.0, volume=1.0, id='fc82b9da'), vo_timing_strategy=None, order=2, id='5091393f')

# %%
# Testimonial segment
testimonial_segment = segments[3]
testimonial_segment
# Out:
# StorySegment(segment_type=<SegmentType.VIDEO_CLIP: 'video_clip'>, content=VideoSegment(source_video_id='c0b7b95110a4', source_path=PosixPath('/Users/amineka/Downloads/Navan_Content/normalized_videos/Fever-Tree_adopts_Navan_for_control_and_proactive_travel_and_expense_management_46.mp4'), start_time=173.8, end_time=192.210958, description='A Fever-Tree representative emphasizes the real-time visibility and reporting offered by Navan, enabling them to understand and track costs against budget as they happen.', keep_original_audio=False, audio_volume=1.0), voice_over=VoiceOver(script='Navan seamlessly syncs with your ERP and accounting tools, providing real-time visibility into spending. Say goodbye to manual exports and uploads, and hello to cleaner books and faster month-end closes. Your finance team gets their time back to focus on strategic initiatives.', audio_path=PosixPath('/var/folders/3v/hwmhcj3912587f0tqnv0wg3w0000gn/T/voice_over_oekw0bd0/vo_f40b5a0e.wav'), duration=18.410958, voice='Kore', speed=1.0, volume=1.0, id='cb59e8b1'), vo_timing_strategy=None, order=3, id='79a00365')

# %%
from videoagent.editor import VideoEditor

editor = VideoEditor(config)
result = editor.render_segments(segments, 'story_playground.mp4')
result
# Out:
# Rendering segment 1/5...
# Rendering segment 2/5...
# Rendering segment 3/5...
# Rendering segment 4/5...
# Rendering segment 5/5...
# Concatenating segments...
# RenderResult(success=True, output_path=PosixPath('/Users/amineka/videoagent/backend/notebooks/output/story_playground.mp4'), duration=79.061, file_size=14688324, error_message=None, timing_adjustments=[])
